# %%
import os
import tempfile
import glob
import numpy as np
import tsplib95 as tsp

import gymnasium as gym
from gymnasium import Env
from gymnasium.spaces import Discrete, Box

from stable_baselines3 import PPO, A2C, DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import EvalCallback

# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
def load_tsp(problem_file):
    problem_path = os.path.join(problem_file)
    problem = tsp.load(problem_path)
    return problem

# %%
gr24 = load_tsp("gr24.tsp")
#print(gr24)
gr24_opt = load_tsp("gr24.opt.tour")
#print(gr24_opt)

# %%
class tspEnv(Env):
    def __init__(self, problem):
        self.problem = problem
        self.action_space = Discrete(self.problem.dimension)
        self.observation_space = Box(0, np.inf, (self.problem.dimension,))
        self.tour = []
        self.max_length = 2*self.problem.dimension
        self.start = 0
        self.large_reward = 10**4
        self.w_matrix = self._get_w_matrix()
        
        
    def step(self, action):
         # Get current state
        state = self._get_state()
        new_obs = self._get_obs(action)

        # Get reward for such a move
        reward = self._get_reward(state,action)

        # Append reached node to tour
        self.tour.append(int(action))
        self._update_matrix(action, self.large_reward)
        
        tour_sort = self.tour.copy()
        tour_sort.sort()
        
        done = False
        force_stop = False
        if (action == self.start) and self._is_subset(list(range(self.problem.dimension)), self.tour):
            done = True
            reward += self.large_reward
            if len(self.tour) == self.problem.dimension + 1:
                reward += self.large_reward
        
        if len(self.tour) == self.max_length:
            force_stop = True

        info = {"tour": self.tour}

        return new_obs, reward, done, force_stop, info

    def next_rand_action(self):
        if len(self.tour) == (self.problem.dimension):
            return self.start
        else:
            while True:
                a = self.action_space.sample()
                if (((a not in self.tour) and (a != self.start)) and (a != self._get_state())):
                    break
            return a
        
    def render(self):
        pass
        
    def reset(self, seed = None, option = None):
        super().reset(seed=seed)
        self.tour = []
        self.start = 0
        self.tour.append(self.start)
        self.w_matrix = self._get_w_matrix()
        self._update_matrix(self.start, self.large_reward/10)
        info = {}
        return self._get_obs(self.start), info

    def _get_state(self):
        return self.tour[-1]

    def _get_reward(self, state, new_state):
        return -self.w_matrix[state][new_state]

    def _get_obs(self, action):
        return np.array(self.w_matrix[action])

    def _get_w_matrix(self):
        data = []
        weight = []
        for i in self.problem.edge_weights:
            for j in i:
                data.append(j)

        # convert lower triangle matrix to square matrix
        if self.problem.edge_weight_format == "LOWER_DIAG_ROW":
            for x in range(self.problem.dimension):   # format lower triangle matrix
                node = []
                w = data.pop(0)
                while w != 0:
                    node.append(w)
                    w = data.pop(0)
                while len(node) != self.problem.dimension:
                    node.append(0)
                weight.append(node)
            matrix = np.triu(np.array(weight).T,1) + weight   #convert to square matrix
            
        matrix[matrix == 0] = self.large_reward
        return matrix

    def _update_matrix(self, new_state, reward):
        self.w_matrix[:, new_state] = reward

    def _is_subset(self, sub_list, list):
        if set(sub_list).intersection(set(list)) == set(sub_list):
            return True
        else:
            return False

# %%
env = tspEnv(gr24)

# %%
episode = 5
for episode in range(episode):
    obs = env.reset()
    done = False
    score = 0

    while not done:
        action = env.next_rand_action()
        obs, reward, done, force_stop, info = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode, score-10**5))
    print(env.tour)
env.close
# Out:
# Episode:0 Score:-83912
# [0, 14, 17, 9, 18, 21, 16, 11, 20, 2, 4, 19, 7, 13, 6, 3, 23, 22, 1, 8, 12, 10, 15, 5, 0]
# Episode:1 Score:-84268
# [0, 11, 9, 23, 20, 2, 19, 3, 12, 15, 14, 5, 7, 4, 1, 16, 21, 6, 17, 10, 8, 22, 18, 13, 0]
# Episode:2 Score:-84306
# [0, 21, 11, 22, 3, 4, 5, 8, 20, 10, 14, 1, 17, 9, 15, 23, 19, 13, 6, 7, 18, 12, 2, 16, 0]
# Episode:3 Score:-84658
# [0, 13, 2, 1, 20, 5, 16, 4, 23, 14, 9, 10, 17, 21, 15, 11, 22, 7, 8, 18, 12, 6, 3, 19, 0]
# Episode:4 Score:-84264
# [0, 12, 6, 20, 17, 5, 16, 3, 18, 19, 8, 2, 10, 4, 22, 11, 15, 9, 14, 23, 7, 13, 21, 1, 0]
# <bound method Env.close of <__main__.tspEnv object at 0x00000277CBD7A720>>

# %%
env.reset()
# Out:
# (array([1000,  257,  187,   91,  150,   80,  130,  134,  243,  185,  214,
#           70,  272,  219,  293,   54,  211,  290,  268,  261,  175,  250,
#          192,  121]),
#  {})

# %%
log_path = os.path.join('Training', 'Logs')
save_path = os.path.join('Training', 'Saved Models')
# Separate evaluation env
eval_env = tspEnv(gr24)
# Use deterministic actions for evaluation
eval_callback = EvalCallback(eval_env, best_model_save_path = save_path,
                             eval_freq = 10000,
                             deterministic=True, render=False)
timesteps = 1000000

# %%
model1 = PPO('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)
model1.learn(total_timesteps = timesteps)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training\Logs\PPO_1
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 47        |
# |    ep_rew_mean     | -2.63e+05 |
# | time/              |           |
# |    fps             | 375       |
# |    iterations      | 1         |
# |    time_elapsed    | 5         |
# |    total_timesteps | 2048      |
# ----------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.65e+05     |
# | time/                   |               |
# |    fps                  | 312           |
# |    iterations           | 2             |
# |    time_elapsed         | 13            |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 1.7276034e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 4.05e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.64e+09      |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -6.64e-05     |
# |    value_loss           | 6.11e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.66e+05     |
# | time/                   |               |
# |    fps                  | 296           |
# |    iterations           | 3             |
# |    time_elapsed         | 20            |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 7.7765435e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | -1.75e-05     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.3e+09       |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -4.32e-05     |
# |    value_loss           | 6.14e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.65e+05     |
# | time/                   |               |
# |    fps                  | 290           |
# |    iterations           | 4             |
# |    time_elapsed         | 28            |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 1.4487887e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 1.25e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.03e+09      |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -5.26e-05     |
# |    value_loss           | 6.18e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.64e+05     |
# | time/                   |               |
# |    fps                  | 288           |
# |    iterations           | 5             |
# |    time_elapsed         | 35            |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 1.3233512e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 5.01e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.82e+09      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -5.13e-05     |
# |    value_loss           | 6e+09         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.65e+05     |
# | time/                   |               |
# |    fps                  | 286           |
# |    iterations           | 6             |
# |    time_elapsed         | 42            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 1.8166611e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 3.46e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.82e+09      |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -6.34e-05     |
# |    value_loss           | 6.08e+09      |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 47             |
# |    ep_rew_mean          | -2.64e+05      |
# | time/                   |                |
# |    fps                  | 284            |
# |    iterations           | 7              |
# |    time_elapsed         | 50             |
# |    total_timesteps      | 14336          |
# | train/                  |                |
# |    approx_kl            | 1.06025254e-07 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -3.18          |
# |    explained_variance   | 3.4e-06        |
# |    learning_rate        | 0.0003         |
# |    loss                 | 3.44e+09       |
# |    n_updates            | 60             |
# |    policy_gradient_loss | -4.94e-05      |
# |    value_loss           | 6.04e+09       |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.66e+05     |
# | time/                   |               |
# |    fps                  | 284           |
# |    iterations           | 8             |
# |    time_elapsed         | 57            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 1.2564124e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 2.92e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.68e+09      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -5.17e-05     |
# |    value_loss           | 6.06e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.64e+05     |
# | time/                   |               |
# |    fps                  | 285           |
# |    iterations           | 9             |
# |    time_elapsed         | 64            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 8.1636244e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 1.91e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.05e+09      |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -5e-05        |
# |    value_loss           | 6.1e+09       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 47           |
# |    ep_rew_mean          | -2.63e+05    |
# | time/                   |              |
# |    fps                  | 285          |
# |    iterations           | 10           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 9.834184e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.18        |
# |    explained_variance   | 8.94e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.71e+09     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -4.54e-05    |
# |    value_loss           | 5.98e+09     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.64e+05     |
# | time/                   |               |
# |    fps                  | 285           |
# |    iterations           | 11            |
# |    time_elapsed         | 78            |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 1.8885476e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 1.31e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.2e+09       |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -6.15e-05     |
# |    value_loss           | 5.96e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.65e+05     |
# | time/                   |               |
# |    fps                  | 282           |
# |    iterations           | 12            |
# |    time_elapsed         | 86            |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 1.9351137e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 9.54e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.05e+09      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -6.95e-05     |
# |    value_loss           | 6.16e+09      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 47           |
# |    ep_rew_mean          | -2.65e+05    |
# | time/                   |              |
# |    fps                  | 278          |
# |    iterations           | 13           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 7.846393e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.18        |
# |    explained_variance   | 5.36e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.28e+09     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -4.54e-05    |
# |    value_loss           | 6.12e+09     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.64e+05     |
# | time/                   |               |
# |    fps                  | 277           |
# |    iterations           | 14            |
# |    time_elapsed         | 103           |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 1.7037382e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 4.17e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.05e+09      |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -5.89e-05     |
# |    value_loss           | 6.06e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.65e+05     |
# | time/                   |               |
# |    fps                  | 276           |
# |    iterations           | 15            |
# |    time_elapsed         | 111           |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 2.0771404e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 7.15e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.98e+09      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -7.18e-05     |
# |    value_loss           | 6.19e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.65e+05     |
# | time/                   |               |
# |    fps                  | 276           |
# |    iterations           | 16            |
# |    time_elapsed         | 118           |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 1.5087426e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 2.38e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.98e+09      |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -5.73e-05     |
# |    value_loss           | 6.08e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.65e+05     |
# | time/                   |               |
# |    fps                  | 276           |
# |    iterations           | 17            |
# |    time_elapsed         | 126           |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 1.6749254e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 3.58e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.73e+09      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -6.06e-05     |
# |    value_loss           | 6.11e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.66e+05     |
# | time/                   |               |
# |    fps                  | 276           |
# |    iterations           | 18            |
# |    time_elapsed         | 133           |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 2.1251617e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 4.77e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.03e+09      |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -7.54e-05     |
# |    value_loss           | 6.11e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.65e+05     |
# | time/                   |               |
# |    fps                  | 276           |
# |    iterations           | 19            |
# |    time_elapsed         | 140           |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 2.0404696e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 2.98e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.22e+09      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -7.31e-05     |
# |    value_loss           | 6.26e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.65e+05     |
# | time/                   |               |
# |    fps                  | 274           |
# |    iterations           | 20            |
# |    time_elapsed         | 149           |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 1.8224819e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.84e+09      |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -6.9e-05      |
# |    value_loss           | 6.18e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.65e+05     |
# | time/                   |               |
# |    fps                  | 272           |
# |    iterations           | 21            |
# |    time_elapsed         | 158           |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 1.8149149e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.04e+09      |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -6.61e-05     |
# |    value_loss           | 6.1e+09       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 47           |
# |    ep_rew_mean          | -2.66e+05    |
# | time/                   |              |
# |    fps                  | 271          |
# |    iterations           | 22           |
# |    time_elapsed         | 165          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 2.347515e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.18        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.87e+09     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -7.65e-05    |
# |    value_loss           | 6.12e+09     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.67e+05     |
# | time/                   |               |
# |    fps                  | 269           |
# |    iterations           | 23            |
# |    time_elapsed         | 175           |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 1.4549005e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.16e+09      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -6.12e-05     |
# |    value_loss           | 6.22e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.66e+05     |
# | time/                   |               |
# |    fps                  | 266           |
# |    iterations           | 24            |
# |    time_elapsed         | 184           |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 1.2468081e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.35e+09      |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -4.69e-05     |
# |    value_loss           | 6.19e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.64e+05     |
# | time/                   |               |
# |    fps                  | 262           |
# |    iterations           | 25            |
# |    time_elapsed         | 195           |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 1.7229468e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.18e+09      |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -6.18e-05     |
# |    value_loss           | 6.19e+09      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 47           |
# |    ep_rew_mean          | -2.65e+05    |
# | time/                   |              |
# |    fps                  | 259          |
# |    iterations           | 26           |
# |    time_elapsed         | 204          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 9.869109e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.18        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.08e+09     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -4.56e-05    |
# |    value_loss           | 6.1e+09      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.66e+05     |
# | time/                   |               |
# |    fps                  | 256           |
# |    iterations           | 27            |
# |    time_elapsed         | 215           |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 1.8317951e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.15e+09      |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -6.46e-05     |
# |    value_loss           | 6.23e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.66e+05     |
# | time/                   |               |
# |    fps                  | 255           |
# |    iterations           | 28            |
# |    time_elapsed         | 224           |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 1.2372038e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.11e+09      |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -5.29e-05     |
# |    value_loss           | 6.12e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.66e+05     |
# | time/                   |               |
# |    fps                  | 254           |
# |    iterations           | 29            |
# |    time_elapsed         | 233           |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 2.1024607e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.08e+09      |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -7.27e-05     |
# |    value_loss           | 6.22e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.64e+05     |
# | time/                   |               |
# |    fps                  | 252           |
# |    iterations           | 30            |
# |    time_elapsed         | 243           |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 2.1627056e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.21e+09      |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -7.08e-05     |
# |    value_loss           | 6.17e+09      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 47           |
# |    ep_rew_mean          | -2.66e+05    |
# | time/                   |              |
# |    fps                  | 250          |
# |    iterations           | 31           |
# |    time_elapsed         | 253          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 2.453453e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.18        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.91e+09     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -8.01e-05    |
# |    value_loss           | 5.96e+09     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.67e+05     |
# | time/                   |               |
# |    fps                  | 248           |
# |    iterations           | 32            |
# |    time_elapsed         | 264           |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 2.5393092e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.89e+09      |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -8.35e-05     |
# |    value_loss           | 6.38e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.64e+05     |
# | time/                   |               |
# |    fps                  | 246           |
# |    iterations           | 33            |
# |    time_elapsed         | 274           |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 1.4022226e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 2.38e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.07e+09      |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -5.3e-05      |
# |    value_loss           | 6.17e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.63e+05     |
# | time/                   |               |
# |    fps                  | 244           |
# |    iterations           | 34            |
# |    time_elapsed         | 285           |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 1.9476283e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 2.38e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.03e+09      |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -6.56e-05     |
# |    value_loss           | 5.99e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.64e+05     |
# | time/                   |               |
# |    fps                  | 242           |
# |    iterations           | 35            |
# |    time_elapsed         | 295           |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 1.5151454e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.25e+09      |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -6.2e-05      |
# |    value_loss           | 6.12e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.66e+05     |
# | time/                   |               |
# |    fps                  | 239           |
# |    iterations           | 36            |
# |    time_elapsed         | 307           |
# |    total_timesteps      | 73728         |
# | train/                  |               |
# |    approx_kl            | 1.6298145e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.12e+09      |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -6.49e-05     |
# |    value_loss           | 6.03e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.66e+05     |
# | time/                   |               |
# |    fps                  | 238           |
# |    iterations           | 37            |
# |    time_elapsed         | 318           |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 1.2925011e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.04e+09      |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -5.65e-05     |
# |    value_loss           | 6.23e+09      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 47           |
# |    ep_rew_mean          | -2.64e+05    |
# | time/                   |              |
# |    fps                  | 236          |
# |    iterations           | 38           |
# |    time_elapsed         | 328          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 1.724402e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.18        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.09e+09     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -6.1e-05     |
# |    value_loss           | 5.97e+09     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.65e+05     |
# | time/                   |               |
# |    fps                  | 235           |
# |    iterations           | 39            |
# |    time_elapsed         | 339           |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 1.6245758e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.88e+09      |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -5.75e-05     |
# |    value_loss           | 6.05e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.66e+05     |
# | time/                   |               |
# |    fps                  | 234           |
# |    iterations           | 40            |
# |    time_elapsed         | 349           |
# |    total_timesteps      | 81920         |
# | train/                  |               |
# |    approx_kl            | 1.7360435e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.92e+09      |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -6.55e-05     |
# |    value_loss           | 6.17e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.66e+05     |
# | time/                   |               |
# |    fps                  | 232           |
# |    iterations           | 41            |
# |    time_elapsed         | 360           |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 1.6170088e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.45e+09      |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -5.77e-05     |
# |    value_loss           | 6.23e+09      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 47           |
# |    ep_rew_mean          | -2.63e+05    |
# | time/                   |              |
# |    fps                  | 231          |
# |    iterations           | 42           |
# |    time_elapsed         | 371          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 9.703217e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.18        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.79e+09     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -4.79e-05    |
# |    value_loss           | 6.1e+09      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.64e+05     |
# | time/                   |               |
# |    fps                  | 230           |
# |    iterations           | 43            |
# |    time_elapsed         | 381           |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 1.5963451e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.06e+09      |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -5.88e-05     |
# |    value_loss           | 6.05e+09      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 47           |
# |    ep_rew_mean          | -2.66e+05    |
# | time/                   |              |
# |    fps                  | 229          |
# |    iterations           | 44           |
# |    time_elapsed         | 392          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 1.610606e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.18        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.92e+09     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -6.02e-05    |
# |    value_loss           | 6.2e+09      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.66e+05     |
# | time/                   |               |
# |    fps                  | 229           |
# |    iterations           | 45            |
# |    time_elapsed         | 402           |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 1.2901728e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.06e+09      |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -5.33e-05     |
# |    value_loss           | 6.21e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.67e+05     |
# | time/                   |               |
# |    fps                  | 228           |
# |    iterations           | 46            |
# |    time_elapsed         | 412           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 1.5404657e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.11e+09      |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -5.68e-05     |
# |    value_loss           | 6.26e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.67e+05     |
# | time/                   |               |
# |    fps                  | 227           |
# |    iterations           | 47            |
# |    time_elapsed         | 423           |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 1.2450619e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.86e+09      |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -5.53e-05     |
# |    value_loss           | 6.19e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.66e+05     |
# | time/                   |               |
# |    fps                  | 226           |
# |    iterations           | 48            |
# |    time_elapsed         | 433           |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 1.4170655e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.21e+09      |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -5.7e-05      |
# |    value_loss           | 6.14e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.66e+05     |
# | time/                   |               |
# |    fps                  | 226           |
# |    iterations           | 49            |
# |    time_elapsed         | 443           |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 1.0099029e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 2.38e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.99e+09      |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -4.93e-05     |
# |    value_loss           | 6.06e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.65e+05     |
# | time/                   |               |
# |    fps                  | 225           |
# |    iterations           | 50            |
# |    time_elapsed         | 454           |
# |    total_timesteps      | 102400        |
# | train/                  |               |
# |    approx_kl            | 1.3774843e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.21e+09      |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -5.67e-05     |
# |    value_loss           | 6.14e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.66e+05     |
# | time/                   |               |
# |    fps                  | 224           |
# |    iterations           | 51            |
# |    time_elapsed         | 464           |
# |    total_timesteps      | 104448        |
# | train/                  |               |
# |    approx_kl            | 1.7837738e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.94e+09      |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -6.25e-05     |
# |    value_loss           | 6.01e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.66e+05     |
# | time/                   |               |
# |    fps                  | 224           |
# |    iterations           | 52            |
# |    time_elapsed         | 475           |
# |    total_timesteps      | 106496        |
# | train/                  |               |
# |    approx_kl            | 2.0116568e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.96e+09      |
# |    n_updates            | 510           |
# |    policy_gradient_loss | -7.01e-05     |
# |    value_loss           | 6.22e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.66e+05     |
# | time/                   |               |
# |    fps                  | 223           |
# |    iterations           | 53            |
# |    time_elapsed         | 485           |
# |    total_timesteps      | 108544        |
# | train/                  |               |
# |    approx_kl            | 1.7505954e-07 |
# |    clip_fraction        | 0             |
# ...
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.18e+09      |
# |    n_updates            | 800           |
# |    policy_gradient_loss | -5.19e-05     |
# |    value_loss           | 6.39e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 46.9          |
# |    ep_rew_mean          | -2.65e+05     |
# | time/                   |               |
# |    fps                  | 212           |
# |    iterations           | 82            |
# |    time_elapsed         | 790           |
# |    total_timesteps      | 167936        |
# | train/                  |               |
# |    approx_kl            | 1.3795216e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.1e+09       |
# |    n_updates            | 810           |
# |    policy_gradient_loss | -5.75e-05     |
# |    value_loss           | 6.2e+09       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.65e+05     |
# | time/                   |               |
# |    fps                  | 212           |
# |    iterations           | 83            |
# |    time_elapsed         | 801           |
# |    total_timesteps      | 169984        |
# | train/                  |               |
# |    approx_kl            | 1.4854595e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.95e+09      |
# |    n_updates            | 820           |
# |    policy_gradient_loss | -5.6e-05      |
# |    value_loss           | 6e+09         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.67e+05     |
# | time/                   |               |
# |    fps                  | 211           |
# |    iterations           | 84            |
# |    time_elapsed         | 812           |
# |    total_timesteps      | 172032        |
# | train/                  |               |
# |    approx_kl            | 1.0171789e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.39e+09      |
# |    n_updates            | 830           |
# |    policy_gradient_loss | -4.9e-05      |
# |    value_loss           | 6.1e+09       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.67e+05     |
# | time/                   |               |
# |    fps                  | 211           |
# |    iterations           | 85            |
# |    time_elapsed         | 822           |
# |    total_timesteps      | 174080        |
# | train/                  |               |
# |    approx_kl            | 2.2703898e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.99e+09      |
# |    n_updates            | 840           |
# |    policy_gradient_loss | -7.43e-05     |
# |    value_loss           | 6.13e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.64e+05     |
# | time/                   |               |
# |    fps                  | 211           |
# |    iterations           | 86            |
# |    time_elapsed         | 833           |
# |    total_timesteps      | 176128        |
# | train/                  |               |
# |    approx_kl            | 1.2351666e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.24e+09      |
# |    n_updates            | 850           |
# |    policy_gradient_loss | -4.92e-05     |
# |    value_loss           | 6.12e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.64e+05     |
# | time/                   |               |
# |    fps                  | 211           |
# |    iterations           | 87            |
# |    time_elapsed         | 843           |
# |    total_timesteps      | 178176        |
# | train/                  |               |
# |    approx_kl            | 1.9790605e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.84e+09      |
# |    n_updates            | 860           |
# |    policy_gradient_loss | -7.48e-05     |
# |    value_loss           | 5.89e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.65e+05     |
# | time/                   |               |
# |    fps                  | 210           |
# |    iterations           | 88            |
# |    time_elapsed         | 854           |
# |    total_timesteps      | 180224        |
# | train/                  |               |
# |    approx_kl            | 1.4866237e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.85e+09      |
# |    n_updates            | 870           |
# |    policy_gradient_loss | -5.79e-05     |
# |    value_loss           | 6.28e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.67e+05     |
# | time/                   |               |
# |    fps                  | 210           |
# |    iterations           | 89            |
# |    time_elapsed         | 864           |
# |    total_timesteps      | 182272        |
# | train/                  |               |
# |    approx_kl            | 2.3189932e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.2e+09       |
# |    n_updates            | 880           |
# |    policy_gradient_loss | -7.74e-05     |
# |    value_loss           | 6.2e+09       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.66e+05     |
# | time/                   |               |
# |    fps                  | 210           |
# |    iterations           | 90            |
# |    time_elapsed         | 875           |
# |    total_timesteps      | 184320        |
# | train/                  |               |
# |    approx_kl            | 1.1984957e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.4e+09       |
# |    n_updates            | 890           |
# |    policy_gradient_loss | -5.1e-05      |
# |    value_loss           | 6.31e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.66e+05     |
# | time/                   |               |
# |    fps                  | 210           |
# |    iterations           | 91            |
# |    time_elapsed         | 885           |
# |    total_timesteps      | 186368        |
# | train/                  |               |
# |    approx_kl            | 1.8550782e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.67e+09      |
# |    n_updates            | 900           |
# |    policy_gradient_loss | -6.9e-05      |
# |    value_loss           | 6.2e+09       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.67e+05     |
# | time/                   |               |
# |    fps                  | 210           |
# |    iterations           | 92            |
# |    time_elapsed         | 895           |
# |    total_timesteps      | 188416        |
# | train/                  |               |
# |    approx_kl            | 1.3152021e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.76e+09      |
# |    n_updates            | 910           |
# |    policy_gradient_loss | -5.54e-05     |
# |    value_loss           | 6.13e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.67e+05     |
# | time/                   |               |
# |    fps                  | 210           |
# |    iterations           | 93            |
# |    time_elapsed         | 906           |
# |    total_timesteps      | 190464        |
# | train/                  |               |
# |    approx_kl            | 1.7875573e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.25e+09      |
# |    n_updates            | 920           |
# |    policy_gradient_loss | -7.02e-05     |
# |    value_loss           | 6.16e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.66e+05     |
# | time/                   |               |
# |    fps                  | 209           |
# |    iterations           | 94            |
# |    time_elapsed         | 916           |
# |    total_timesteps      | 192512        |
# | train/                  |               |
# |    approx_kl            | 1.2182863e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.97e+09      |
# |    n_updates            | 930           |
# |    policy_gradient_loss | -5.09e-05     |
# |    value_loss           | 6.19e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.66e+05     |
# | time/                   |               |
# |    fps                  | 209           |
# |    iterations           | 95            |
# |    time_elapsed         | 927           |
# |    total_timesteps      | 194560        |
# | train/                  |               |
# |    approx_kl            | 1.4618854e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.01e+09      |
# |    n_updates            | 940           |
# |    policy_gradient_loss | -6.01e-05     |
# |    value_loss           | 6.13e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.64e+05     |
# | time/                   |               |
# |    fps                  | 209           |
# |    iterations           | 96            |
# |    time_elapsed         | 937           |
# |    total_timesteps      | 196608        |
# | train/                  |               |
# |    approx_kl            | 1.6496051e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.2e+09       |
# |    n_updates            | 950           |
# |    policy_gradient_loss | -6.2e-05      |
# |    value_loss           | 6.04e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.63e+05     |
# | time/                   |               |
# |    fps                  | 209           |
# |    iterations           | 97            |
# |    time_elapsed         | 947           |
# |    total_timesteps      | 198656        |
# | train/                  |               |
# |    approx_kl            | 1.2328383e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.82e+09      |
# |    n_updates            | 960           |
# |    policy_gradient_loss | -5.31e-05     |
# |    value_loss           | 5.9e+09       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 47            |
# |    ep_rew_mean          | -2.65e+05     |
# | time/                   |               |
# |    fps                  | 209           |
# |    iterations           | 98            |
# |    time_elapsed         | 958           |
# |    total_timesteps      | 200704        |
# | train/                  |               |
# |    approx_kl            | 1.9063009e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.18         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.85e+09      |
# |    n_updates            | 970           |
# |    policy_gradient_loss | -6.6e-05      |
# |    value_loss           | 6.07e+09      |
# -------------------------------------------

# %%
model2 = A2C('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)
model2.learn(total_timesteps = timesteps)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training\Logs\A2C_1
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.68e+05 |
# | time/                 |           |
# |    fps                | 188       |
# |    iterations         | 100       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -3.03     |
# |    explained_variance | -5.02e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | -4.51e+04 |
# |    value_loss         | 2.68e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.74e+05 |
# | time/                 |           |
# |    fps                | 187       |
# |    iterations         | 200       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -3.16     |
# |    explained_variance | -0.00504  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -3.62e+04 |
# |    value_loss         | 1.16e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.73e+05 |
# | time/                 |           |
# |    fps                | 188       |
# |    iterations         | 300       |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -3.08     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -7.84e+04 |
# |    value_loss         | 7.6e+08   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.73e+05 |
# | time/                 |           |
# |    fps                | 188       |
# |    iterations         | 400       |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -3.14     |
# |    explained_variance | -2.96e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | -3.75e+04 |
# |    value_loss         | 1.63e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.72e+05 |
# | time/                 |           |
# |    fps                | 187       |
# |    iterations         | 500       |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -3.16     |
# |    explained_variance | 0.00128   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | -1.06e+04 |
# |    value_loss         | 2.12e+07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.71e+05 |
# | time/                 |           |
# |    fps                | 186       |
# |    iterations         | 600       |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -3.14     |
# |    explained_variance | -3.58e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | -7.19e+04 |
# |    value_loss         | 6.24e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.7e+05  |
# | time/                 |           |
# |    fps                | 185       |
# |    iterations         | 700       |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -3.14     |
# |    explained_variance | -1.59e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -3.63e+04 |
# |    value_loss         | 1.65e+08  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 47       |
# |    ep_rew_mean        | -2.7e+05 |
# | time/                 |          |
# |    fps                | 186      |
# |    iterations         | 800      |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -3.06    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -6.2e+04 |
# |    value_loss         | 4.56e+08 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.7e+05  |
# | time/                 |           |
# |    fps                | 185       |
# |    iterations         | 900       |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -3.14     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | -8.89e+04 |
# |    value_loss         | 8.92e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.7e+05  |
# | time/                 |           |
# |    fps                | 185       |
# |    iterations         | 1000      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -3.15     |
# |    explained_variance | -8.23e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -5.56e+04 |
# |    value_loss         | 3.77e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.69e+05 |
# | time/                 |           |
# |    fps                | 185       |
# |    iterations         | 1100      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -3.15     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -8.24e+04 |
# |    value_loss         | 7.82e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.68e+05 |
# | time/                 |           |
# |    fps                | 184       |
# |    iterations         | 1200      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -3.13     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | -3.95e+04 |
# |    value_loss         | 2.21e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.67e+05 |
# | time/                 |           |
# |    fps                | 184       |
# |    iterations         | 1300      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -3.15     |
# |    explained_variance | -0.00337  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | -1.45e+03 |
# |    value_loss         | 2.45e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.65e+05 |
# | time/                 |           |
# |    fps                | 184       |
# |    iterations         | 1400      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -3.1      |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | -8.64e+04 |
# |    value_loss         | 1.07e+09  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.67e+05 |
# | time/                 |           |
# |    fps                | 184       |
# |    iterations         | 1500      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -3.14     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -4.11e+04 |
# |    value_loss         | 2.8e+08   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.67e+05 |
# | time/                 |           |
# |    fps                | 184       |
# |    iterations         | 1600      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -3.14     |
# |    explained_variance | 0.000252  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -1.43e+04 |
# |    value_loss         | 4.32e+07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.67e+05 |
# | time/                 |           |
# |    fps                | 184       |
# |    iterations         | 1700      |
# |    time_elapsed       | 46        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -3.13     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -8.99e+04 |
# |    value_loss         | 1.07e+09  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.67e+05 |
# | time/                 |           |
# |    fps                | 183       |
# |    iterations         | 1800      |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -3.15     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | -3.91e+04 |
# |    value_loss         | 2.03e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.67e+05 |
# | time/                 |           |
# |    fps                | 183       |
# |    iterations         | 1900      |
# |    time_elapsed       | 51        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -3.12     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | -6.66e+04 |
# |    value_loss         | 5.86e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.67e+05 |
# | time/                 |           |
# |    fps                | 183       |
# |    iterations         | 2000      |
# |    time_elapsed       | 54        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -3.13     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | -7.84e+04 |
# |    value_loss         | 6.67e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.67e+05 |
# | time/                 |           |
# |    fps                | 182       |
# |    iterations         | 2100      |
# |    time_elapsed       | 57        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -3.15     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | -3.96e+04 |
# |    value_loss         | 1.63e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.67e+05 |
# | time/                 |           |
# |    fps                | 183       |
# |    iterations         | 2200      |
# |    time_elapsed       | 59        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -3.09     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | -7.03e+04 |
# |    value_loss         | 6.59e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.67e+05 |
# | time/                 |           |
# |    fps                | 182       |
# |    iterations         | 2300      |
# |    time_elapsed       | 62        |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -3.08     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2299      |
# |    policy_loss        | -6.35e+04 |
# |    value_loss         | 5.27e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.66e+05 |
# | time/                 |           |
# |    fps                | 182       |
# |    iterations         | 2400      |
# |    time_elapsed       | 65        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -3.08     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2399      |
# |    policy_loss        | -2.82e+04 |
# |    value_loss         | 1.24e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.66e+05 |
# | time/                 |           |
# |    fps                | 182       |
# |    iterations         | 2500      |
# |    time_elapsed       | 68        |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -3.01     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2499      |
# |    policy_loss        | -7.96e+04 |
# |    value_loss         | 6.59e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.66e+05 |
# | time/                 |           |
# |    fps                | 183       |
# |    iterations         | 2600      |
# |    time_elapsed       | 70        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -3.07     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | -3.96e+04 |
# |    value_loss         | 2.15e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.64e+05 |
# | time/                 |           |
# |    fps                | 184       |
# |    iterations         | 2700      |
# |    time_elapsed       | 73        |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -3.12     |
# |    explained_variance | -0.000343 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2699      |
# |    policy_loss        | -2.41e+03 |
# |    value_loss         | 7.16e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.65e+05 |
# | time/                 |           |
# |    fps                | 184       |
# |    iterations         | 2800      |
# |    time_elapsed       | 75        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -3.05     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | -7.04e+04 |
# |    value_loss         | 6.63e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.64e+05 |
# | time/                 |           |
# |    fps                | 184       |
# |    iterations         | 2900      |
# |    time_elapsed       | 78        |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -3.07     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | -5.61e+04 |
# |    value_loss         | 4.55e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.63e+05 |
# | time/                 |           |
# |    fps                | 185       |
# |    iterations         | 3000      |
# |    time_elapsed       | 80        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -3.09     |
# |    explained_variance | 6.56e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | -3.8e+04  |
# |    value_loss         | 2.76e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.63e+05 |
# | time/                 |           |
# |    fps                | 187       |
# |    iterations         | 3100      |
# |    time_elapsed       | 82        |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -3.12     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3099      |
# |    policy_loss        | -9.11e+04 |
# |    value_loss         | 9.06e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.64e+05 |
# | time/                 |           |
# |    fps                | 188       |
# |    iterations         | 3200      |
# |    time_elapsed       | 84        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -3.12     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3199      |
# |    policy_loss        | -5.67e+04 |
# |    value_loss         | 3.37e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.64e+05 |
# | time/                 |           |
# |    fps                | 190       |
# |    iterations         | 3300      |
# |    time_elapsed       | 86        |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -3.07     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3299      |
# |    policy_loss        | -7.37e+04 |
# |    value_loss         | 7.59e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.63e+05 |
# | time/                 |           |
# |    fps                | 191       |
# |    iterations         | 3400      |
# |    time_elapsed       | 88        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -3.12     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | -5.72e+04 |
# |    value_loss         | 4.69e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.63e+05 |
# | time/                 |           |
# |    fps                | 192       |
# |    iterations         | 3500      |
# |    time_elapsed       | 91        |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -3.14     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3499      |
# |    policy_loss        | -5.46e+04 |
# |    value_loss         | 3.38e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.63e+05 |
# | time/                 |           |
# |    fps                | 192       |
# |    iterations         | 3600      |
# |    time_elapsed       | 93        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -3.04     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | -8.15e+04 |
# |    value_loss         | 6.67e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.62e+05 |
# | time/                 |           |
# |    fps                | 193       |
# |    iterations         | 3700      |
# |    time_elapsed       | 95        |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -3.1      |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | -7.52e+04 |
# |    value_loss         | 6.62e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.62e+05 |
# | time/                 |           |
# |    fps                | 194       |
# |    iterations         | 3800      |
# |    time_elapsed       | 97        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -3.1      |
# |    explained_variance | -4.53e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | -3.01e+04 |
# |    value_loss         | 1.03e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.61e+05 |
# | time/                 |           |
# |    fps                | 196       |
# |    iterations         | 3900      |
# |    time_elapsed       | 99        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -3.09     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | -7.84e+04 |
# |    value_loss         | 6.65e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.61e+05 |
# | time/                 |           |
# |    fps                | 197       |
# |    iterations         | 4000      |
# |    time_elapsed       | 101       |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -3.04     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3999      |
# |    policy_loss        | -3.61e+04 |
# |    value_loss         | 2.17e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.62e+05 |
# | time/                 |           |
# |    fps                | 197       |
# |    iterations         | 4100      |
# |    time_elapsed       | 103       |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -3.08     |
# |    explained_variance | -7.96e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4099      |
# |    policy_loss        | -2.74e+04 |
# |    value_loss         | 8.6e+07   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.62e+05 |
# | time/                 |           |
# |    fps                | 198       |
# |    iterations         | 4200      |
# |    time_elapsed       | 105       |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -3.05     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4199      |
# |    policy_loss        | -8.61e+04 |
# |    value_loss         | 1.07e+09  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.61e+05 |
# | time/                 |           |
# |    fps                | 199       |
# |    iterations         | 4300      |
# |    time_elapsed       | 107       |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -3.09     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4299      |
# |    policy_loss        | -5.37e+03 |
# |    value_loss         | 2.21e+07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.6e+05  |
# | time/                 |           |
# |    fps                | 200       |
# |    iterations         | 4400      |
# |    time_elapsed       | 109       |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -3.02     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4399      |
# |    policy_loss        | -5.91e+04 |
# |    value_loss         | 5.86e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.6e+05  |
# | time/                 |           |
# |    fps                | 200       |
# |    iterations         | 4500      |
# |    time_elapsed       | 112       |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -3.06     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | -6.05e+04 |
# |    value_loss         | 3.75e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.61e+05 |
# | time/                 |           |
# |    fps                | 201       |
# |    iterations         | 4600      |
# |    time_elapsed       | 114       |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -3.12     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4599      |
# |    policy_loss        | -1.39e+03 |
# |    value_loss         | 2.81e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.62e+05 |
# | time/                 |           |
# |    fps                | 201       |
# |    iterations         | 4700      |
# |    time_elapsed       | 116       |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -3.11     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4699      |
# |    policy_loss        | -9.13e+04 |
# |    value_loss         | 1.07e+09  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.61e+05 |
# | time/                 |           |
# |    fps                | 202       |
# |    iterations         | 4800      |
# |    time_elapsed       | 118       |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -3.09     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4799      |
# |    policy_loss        | -4.87e+04 |
# |    value_loss         | 3.12e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.62e+05 |
# | time/                 |           |
# |    fps                | 202       |
# |    iterations         | 4900      |
# |    time_elapsed       | 120       |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -3.1      |
# |    explained_variance | -1.43e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4899      |
# |    policy_loss        | -1.56e+03 |
# |    value_loss         | 2.78e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.63e+05 |
# | time/                 |           |
# |    fps                | 203       |
# |    iterations         | 5000      |
# |    time_elapsed       | 122       |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -3.11     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4999      |
# |    policy_loss        | -6.76e+04 |
# |    value_loss         | 6.22e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.63e+05 |
# | time/                 |           |
# |    fps                | 204       |
# |    iterations         | 5100      |
# |    time_elapsed       | 124       |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -3.08     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | -4.61e+04 |
# |    value_loss         | 2.6e+08   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.62e+05 |
# | time/                 |           |
# |    fps                | 204       |
# |    iterations         | 5200      |
# |    time_elapsed       | 126       |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -3.06     |
# |    explained_variance | -3.47e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5199      |
# |    policy_loss        | -1.81e+03 |
# |    value_loss         | 3.9e+05   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.63e+05 |
# | time/                 |           |
# |    fps                | 205       |
# |    iterations         | 5300      |
# |    time_elapsed       | 129       |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -3.01     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | -8.04e+04 |
# |    value_loss         | 1.07e+09  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.62e+05 |
# | time/                 |           |
# |    fps                | 205       |
# |    iterations         | 5400      |
# |    time_elapsed       | 131       |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -3.01     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5399      |
# |    policy_loss        | -4.18e+04 |
# |    value_loss         | 2.61e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.63e+05 |
# | time/                 |           |
# |    fps                | 206       |
# |    iterations         | 5500      |
# |    time_elapsed       | 133       |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -2.99     |
# |    explained_variance | 5.96e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5499      |
# |    policy_loss        | -2e+04    |
# |    value_loss         | 1.01e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.63e+05 |
# | time/                 |           |
# |    fps                | 206       |
# |    iterations         | 5600      |
# |    time_elapsed       | 135       |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -2.97     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5599      |
# |    policy_loss        | -5.95e+04 |
# |    value_loss         | 4.72e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.63e+05 |
# | time/                 |           |
# |    fps                | 207       |
# |    iterations         | 5700      |
# |    time_elapsed       | 137       |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -3        |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5699      |
# |    policy_loss        | -3.61e+04 |
# |    value_loss         | 1.83e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.63e+05 |
# | time/                 |           |
# |    fps                | 208       |
# |    iterations         | 5800      |
# |    time_elapsed       | 139       |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -2.93     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5799      |
# |    policy_loss        | -8.52e+04 |
# |    value_loss         | 7.58e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.63e+05 |
# | time/                 |           |
# |    fps                | 208       |
# |    iterations         | 5900      |
# |    time_elapsed       | 141       |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -3.02     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5899      |
# |    policy_loss        | -8.51e+04 |
# |    value_loss         | 8.91e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.63e+05 |
# | time/                 |           |
# |    fps                | 209       |
# |    iterations         | 6000      |
# |    time_elapsed       | 143       |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -3.08     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5999      |
# |    policy_loss        | -5.78e+04 |
# |    value_loss         | 4.51e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.64e+05 |
# | time/                 |           |
# |    fps                | 209       |
# |    iterations         | 6100      |
# |    time_elapsed       | 145       |
# |    total_timesteps    | 30500     |
# | train/                |           |
# |    entropy_loss       | -3.06     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6099      |
# |    policy_loss        | -6.89e+04 |
# |    value_loss         | 5.43e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.65e+05 |
# | time/                 |           |
# |    fps                | 210       |
# |    iterations         | 6200      |
# |    time_elapsed       | 147       |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -3.02     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6199      |
# |    policy_loss        | -7.85e+04 |
# |    value_loss         | 6.23e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.65e+05 |
# | time/                 |           |
# |    fps                | 211       |
# |    iterations         | 6300      |
# |    time_elapsed       | 149       |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -2.99     |
# |    explained_variance | -1.55e-06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6299      |
# |    policy_loss        | -1.35e+04 |
# |    value_loss         | 4.32e+07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.65e+05 |
# | time/                 |           |
# |    fps                | 211       |
# |    iterations         | 6400      |
# |    time_elapsed       | 151       |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -2.91     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | -7.18e+04 |
# |    value_loss         | 4.26e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.65e+05 |
# | time/                 |           |
# |    fps                | 212       |
# |    iterations         | 6500      |
# |    time_elapsed       | 153       |
# |    total_timesteps    | 32500     |
# | train/                |           |
# |    entropy_loss       | -3.02     |
# |    explained_variance | 2.38e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6499      |
# |    policy_loss        | -4.72e+04 |
# |    value_loss         | 2.83e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.64e+05 |
# | time/                 |           |
# |    fps                | 212       |
# |    iterations         | 6600      |
# |    time_elapsed       | 155       |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -2.97     |
# |    explained_variance | 2.38e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6599      |
# |    policy_loss        | -1.45e+04 |
# |    value_loss         | 4e+07     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.65e+05 |
# | time/                 |           |
# |    fps                | 213       |
# |    iterations         | 6700      |
# |    time_elapsed       | 157       |
# |    total_timesteps    | 33500     |
# | train/                |           |
# |    entropy_loss       | -2.93     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6699      |
# |    policy_loss        | -6.92e+04 |
# |    value_loss         | 7.56e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.66e+05 |
# | time/                 |           |
# |    fps                | 213       |
# |    iterations         | 6800      |
# |    time_elapsed       | 158       |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -3.04     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6799      |
# |    policy_loss        | -7.03e+04 |
# |    value_loss         | 6.62e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.65e+05 |
# | time/                 |           |
# |    fps                | 214       |
# |    iterations         | 6900      |
# |    time_elapsed       | 161       |
# |    total_timesteps    | 34500     |
# | train/                |           |
# |    entropy_loss       | -2.91     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6899      |
# |    policy_loss        | -8.07e+04 |
# |    value_loss         | 8.9e+08   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.65e+05 |
# | time/                 |           |
# |    fps                | 214       |
# |    iterations         | 7000      |
# |    time_elapsed       | 163       |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -2.83     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6999      |
# |    policy_loss        | -5.34e+04 |
# |    value_loss         | 3.78e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.65e+05 |
# | time/                 |           |
# |    fps                | 214       |
# |    iterations         | 7100      |
# |    time_elapsed       | 165       |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -3.03     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | -5.81e+03 |
# |    value_loss         | 2.22e+07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.65e+05 |
# | time/                 |           |
# |    fps                | 214       |
# |    iterations         | 7200      |
# |    time_elapsed       | 167       |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -2.88     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7199      |
# |    policy_loss        | -7.41e+04 |
# |    value_loss         | 6.05e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.66e+05 |
# | time/                 |           |
# |    fps                | 214       |
# |    iterations         | 7300      |
# |    time_elapsed       | 169       |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -2.92     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7299      |
# |    policy_loss        | -6.79e+03 |
# |    value_loss         | 2.36e+07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.66e+05 |
# | time/                 |           |
# |    fps                | 215       |
# |    iterations         | 7400      |
# |    time_elapsed       | 171       |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -3.03     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7399      |
# |    policy_loss        | -7.91e+03 |
# |    value_loss         | 2.26e+07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# ...
# | time/                 |           |
# |    fps                | 209       |
# |    iterations         | 37600     |
# |    time_elapsed       | 897       |
# |    total_timesteps    | 188000    |
# | train/                |           |
# |    entropy_loss       | -2.37     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 37599     |
# |    policy_loss        | -5.95e+04 |
# |    value_loss         | 1.06e+09  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.61e+05 |
# | time/                 |           |
# |    fps                | 209       |
# |    iterations         | 37700     |
# |    time_elapsed       | 900       |
# |    total_timesteps    | 188500    |
# | train/                |           |
# |    entropy_loss       | -1.45     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 37699     |
# |    policy_loss        | -3.84e+04 |
# |    value_loss         | 1.06e+09  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.63e+05 |
# | time/                 |           |
# |    fps                | 209       |
# |    iterations         | 37800     |
# |    time_elapsed       | 902       |
# |    total_timesteps    | 189000    |
# | train/                |           |
# |    entropy_loss       | -2.09     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 37799     |
# |    policy_loss        | -396      |
# |    value_loss         | 1.13e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.63e+05 |
# | time/                 |           |
# |    fps                | 209       |
# |    iterations         | 37900     |
# |    time_elapsed       | 904       |
# |    total_timesteps    | 189500    |
# | train/                |           |
# |    entropy_loss       | -2.03     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 37899     |
# |    policy_loss        | -2.14e+04 |
# |    value_loss         | 1.06e+09  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.64e+05 |
# | time/                 |           |
# |    fps                | 209       |
# |    iterations         | 38000     |
# |    time_elapsed       | 906       |
# |    total_timesteps    | 190000    |
# | train/                |           |
# |    entropy_loss       | -2.08     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 37999     |
# |    policy_loss        | -2.6e+04  |
# |    value_loss         | 1.21e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.65e+05 |
# | time/                 |           |
# |    fps                | 209       |
# |    iterations         | 38100     |
# |    time_elapsed       | 908       |
# |    total_timesteps    | 190500    |
# | train/                |           |
# |    entropy_loss       | -2.31     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 38099     |
# |    policy_loss        | -549      |
# |    value_loss         | 1.16e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.65e+05 |
# | time/                 |           |
# |    fps                | 209       |
# |    iterations         | 38200     |
# |    time_elapsed       | 910       |
# |    total_timesteps    | 191000    |
# | train/                |           |
# |    entropy_loss       | -2.44     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 38199     |
# |    policy_loss        | -6.48e+04 |
# |    value_loss         | 6.07e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.64e+05 |
# | time/                 |           |
# |    fps                | 209       |
# |    iterations         | 38300     |
# |    time_elapsed       | 912       |
# |    total_timesteps    | 191500    |
# | train/                |           |
# |    entropy_loss       | -2.23     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 38299     |
# |    policy_loss        | -8.86e+04 |
# |    value_loss         | 7.53e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.65e+05 |
# | time/                 |           |
# |    fps                | 209       |
# |    iterations         | 38400     |
# |    time_elapsed       | 914       |
# |    total_timesteps    | 192000    |
# | train/                |           |
# |    entropy_loss       | -1.95     |
# |    explained_variance | -3.58e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 38399     |
# |    policy_loss        | -304      |
# |    value_loss         | 7.48e+04  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.65e+05 |
# | time/                 |           |
# |    fps                | 210       |
# |    iterations         | 38500     |
# |    time_elapsed       | 916       |
# |    total_timesteps    | 192500    |
# | train/                |           |
# |    entropy_loss       | -2.67     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 38499     |
# |    policy_loss        | -7.16e+04 |
# |    value_loss         | 1.06e+09  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.64e+05 |
# | time/                 |           |
# |    fps                | 210       |
# |    iterations         | 38600     |
# |    time_elapsed       | 918       |
# |    total_timesteps    | 193000    |
# | train/                |           |
# |    entropy_loss       | -2.15     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 38599     |
# |    policy_loss        | -435      |
# |    value_loss         | 1.65e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.62e+05 |
# | time/                 |           |
# |    fps                | 210       |
# |    iterations         | 38700     |
# |    time_elapsed       | 920       |
# |    total_timesteps    | 193500    |
# | train/                |           |
# |    entropy_loss       | -2.52     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 38699     |
# |    policy_loss        | -4.74e+04 |
# |    value_loss         | 5.84e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.61e+05 |
# | time/                 |           |
# |    fps                | 210       |
# |    iterations         | 38800     |
# |    time_elapsed       | 922       |
# |    total_timesteps    | 194000    |
# | train/                |           |
# |    entropy_loss       | -0.474    |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 38799     |
# |    policy_loss        | -2.31e+03 |
# |    value_loss         | 1.06e+09  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.6e+05  |
# | time/                 |           |
# |    fps                | 210       |
# |    iterations         | 38900     |
# |    time_elapsed       | 924       |
# |    total_timesteps    | 194500    |
# | train/                |           |
# |    entropy_loss       | -1.82     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 38899     |
# |    policy_loss        | -1.67e+04 |
# |    value_loss         | 2.02e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.6e+05  |
# | time/                 |           |
# |    fps                | 210       |
# |    iterations         | 39000     |
# |    time_elapsed       | 926       |
# |    total_timesteps    | 195000    |
# | train/                |           |
# |    entropy_loss       | -1.92     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 38999     |
# |    policy_loss        | -4.19e+04 |
# |    value_loss         | 1.06e+09  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.62e+05 |
# | time/                 |           |
# |    fps                | 210       |
# |    iterations         | 39100     |
# |    time_elapsed       | 928       |
# |    total_timesteps    | 195500    |
# | train/                |           |
# |    entropy_loss       | -2.27     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 39099     |
# |    policy_loss        | -4.01e+04 |
# |    value_loss         | 3.16e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.62e+05 |
# | time/                 |           |
# |    fps                | 210       |
# |    iterations         | 39200     |
# |    time_elapsed       | 930       |
# |    total_timesteps    | 196000    |
# | train/                |           |
# |    entropy_loss       | -2        |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 39199     |
# |    policy_loss        | -780      |
# |    value_loss         | 1.07e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.62e+05 |
# | time/                 |           |
# |    fps                | 210       |
# |    iterations         | 39300     |
# |    time_elapsed       | 931       |
# |    total_timesteps    | 196500    |
# | train/                |           |
# |    entropy_loss       | -2.67     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 39299     |
# |    policy_loss        | -5.49e+04 |
# |    value_loss         | 6.61e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.61e+05 |
# | time/                 |           |
# |    fps                | 210       |
# |    iterations         | 39400     |
# |    time_elapsed       | 933       |
# |    total_timesteps    | 197000    |
# | train/                |           |
# |    entropy_loss       | -2.23     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 39399     |
# |    policy_loss        | -3.62e+04 |
# |    value_loss         | 3.33e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.61e+05 |
# | time/                 |           |
# |    fps                | 211       |
# |    iterations         | 39500     |
# |    time_elapsed       | 935       |
# |    total_timesteps    | 197500    |
# | train/                |           |
# |    entropy_loss       | -1.9      |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 39499     |
# |    policy_loss        | -1.14e+03 |
# |    value_loss         | 2.63e+05  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.62e+05 |
# | time/                 |           |
# |    fps                | 211       |
# |    iterations         | 39600     |
# |    time_elapsed       | 937       |
# |    total_timesteps    | 198000    |
# | train/                |           |
# |    entropy_loss       | -2.44     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 39599     |
# |    policy_loss        | -4.97e+04 |
# |    value_loss         | 3.69e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 47        |
# |    ep_rew_mean        | -2.61e+05 |
# | time/                 |           |
# |    fps                | 211       |
# |    iterations         | 39700     |
# |    time_elapsed       | 939       |
# |    total_timesteps    | 198500    |
# | train/                |           |
# |    entropy_loss       | -2.38     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 39699     |
# |    policy_loss        | -1.28e+04 |
# |    value_loss         | 1.13e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 46.8      |
# |    ep_rew_mean        | -2.58e+05 |
# | time/                 |           |
# |    fps                | 211       |
# |    iterations         | 39800     |
# |    time_elapsed       | 941       |
# |    total_timesteps    | 199000    |
# | train/                |           |
# |    entropy_loss       | -2.25     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 39799     |
# |    policy_loss        | -4.73e+04 |
# |    value_loss         | 7.57e+08  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 46.8      |
# |    ep_rew_mean        | -2.58e+05 |
# | time/                 |           |
# |    fps                | 211       |
# |    iterations         | 39900     |
# |    time_elapsed       | 943       |
# |    total_timesteps    | 199500    |
# | train/                |           |
# |    entropy_loss       | -2.24     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 39899     |
# |    policy_loss        | -9.3e+03  |
# |    value_loss         | 4.16e+07  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 46.8      |
# |    ep_rew_mean        | -2.57e+05 |
# | time/                 |           |
# |    fps                | 211       |
# |    iterations         | 40000     |
# |    time_elapsed       | 945       |
# |    total_timesteps    | 200000    |
# | train/                |           |
# |    entropy_loss       | -2.51     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 39999     |
# |    policy_loss        | -3.21e+04 |
# |    value_loss         | 2.77e+08  |
# -------------------------------------

# %%
model3 = DQN('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)
model3.learn(total_timesteps = timesteps, callback = eval_callback)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to Training\Logs\DQN_2
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.59e+05 |
# |    exploration_rate | 0.998     |
# | time/               |           |
# |    episodes         | 4         |
# |    fps              | 445       |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 188       |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.99e+03  |
# |    n_updates        | 21        |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.64e+05 |
# |    exploration_rate | 0.996     |
# | time/               |           |
# |    episodes         | 8         |
# |    fps              | 548       |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 376       |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.83e+03  |
# |    n_updates        | 68        |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.65e+05 |
# |    exploration_rate | 0.995     |
# | time/               |           |
# |    episodes         | 12        |
# |    fps              | 597       |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 564       |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 5.85e+03  |
# |    n_updates        | 115       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.66e+05 |
# |    exploration_rate | 0.993     |
# | time/               |           |
# |    episodes         | 16        |
# |    fps              | 635       |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 752       |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 5.75e+03  |
# |    n_updates        | 162       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.69e+05 |
# |    exploration_rate | 0.991     |
# | time/               |           |
# |    episodes         | 20        |
# |    fps              | 642       |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 940       |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.35e+03  |
# |    n_updates        | 209       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.69e+05 |
# |    exploration_rate | 0.989     |
# | time/               |           |
# |    episodes         | 24        |
# |    fps              | 659       |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 1128      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 5.13e+03  |
# |    n_updates        | 256       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.68e+05 |
# |    exploration_rate | 0.987     |
# | time/               |           |
# |    episodes         | 28        |
# |    fps              | 672       |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 1316      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 5.37e+03  |
# |    n_updates        | 303       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.67e+05 |
# |    exploration_rate | 0.986     |
# | time/               |           |
# |    episodes         | 32        |
# |    fps              | 681       |
# |    time_elapsed     | 2         |
# |    total_timesteps  | 1504      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 5.64e+03  |
# |    n_updates        | 350       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.68e+05 |
# |    exploration_rate | 0.984     |
# | time/               |           |
# |    episodes         | 36        |
# |    fps              | 694       |
# |    time_elapsed     | 2         |
# |    total_timesteps  | 1692      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.78e+03  |
# |    n_updates        | 397       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.67e+05 |
# |    exploration_rate | 0.982     |
# | time/               |           |
# |    episodes         | 40        |
# |    fps              | 700       |
# |    time_elapsed     | 2         |
# |    total_timesteps  | 1880      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 5.44e+03  |
# |    n_updates        | 444       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.67e+05 |
# |    exploration_rate | 0.98      |
# | time/               |           |
# |    episodes         | 44        |
# |    fps              | 708       |
# |    time_elapsed     | 2         |
# |    total_timesteps  | 2068      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 5.06e+03  |
# |    n_updates        | 491       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.67e+05 |
# |    exploration_rate | 0.979     |
# | time/               |           |
# |    episodes         | 48        |
# |    fps              | 714       |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 2256      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.86e+03  |
# |    n_updates        | 538       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.67e+05 |
# |    exploration_rate | 0.977     |
# | time/               |           |
# |    episodes         | 52        |
# |    fps              | 717       |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 2444      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.76e+03  |
# |    n_updates        | 585       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.67e+05 |
# |    exploration_rate | 0.975     |
# | time/               |           |
# |    episodes         | 56        |
# |    fps              | 723       |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 2632      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.78e+03  |
# |    n_updates        | 632       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.67e+05 |
# |    exploration_rate | 0.973     |
# | time/               |           |
# |    episodes         | 60        |
# |    fps              | 727       |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 2820      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.76e+03  |
# |    n_updates        | 679       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.66e+05 |
# |    exploration_rate | 0.971     |
# | time/               |           |
# |    episodes         | 64        |
# |    fps              | 727       |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 3008      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.38e+03  |
# |    n_updates        | 726       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.66e+05 |
# |    exploration_rate | 0.97      |
# | time/               |           |
# |    episodes         | 68        |
# |    fps              | 731       |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 3196      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.65e+03  |
# |    n_updates        | 773       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.66e+05 |
# |    exploration_rate | 0.968     |
# | time/               |           |
# |    episodes         | 72        |
# |    fps              | 734       |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 3384      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.88e+03  |
# |    n_updates        | 820       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.66e+05 |
# |    exploration_rate | 0.966     |
# | time/               |           |
# |    episodes         | 76        |
# |    fps              | 737       |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 3572      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.34e+03  |
# |    n_updates        | 867       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.66e+05 |
# |    exploration_rate | 0.964     |
# | time/               |           |
# |    episodes         | 80        |
# |    fps              | 739       |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 3760      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.81e+03  |
# |    n_updates        | 914       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.66e+05 |
# |    exploration_rate | 0.962     |
# | time/               |           |
# |    episodes         | 84        |
# |    fps              | 742       |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 3948      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.04e+03  |
# |    n_updates        | 961       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.66e+05 |
# |    exploration_rate | 0.961     |
# | time/               |           |
# |    episodes         | 88        |
# |    fps              | 745       |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 4136      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.28e+03  |
# |    n_updates        | 1008      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.66e+05 |
# |    exploration_rate | 0.959     |
# | time/               |           |
# |    episodes         | 92        |
# |    fps              | 746       |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 4324      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.61e+03  |
# |    n_updates        | 1055      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.67e+05 |
# |    exploration_rate | 0.957     |
# | time/               |           |
# |    episodes         | 96        |
# |    fps              | 748       |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 4512      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.32e+03  |
# |    n_updates        | 1102      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.67e+05 |
# |    exploration_rate | 0.955     |
# | time/               |           |
# |    episodes         | 100       |
# |    fps              | 748       |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 4700      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.77e+03  |
# |    n_updates        | 1149      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.67e+05 |
# |    exploration_rate | 0.954     |
# | time/               |           |
# |    episodes         | 104       |
# |    fps              | 749       |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 4888      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.93e+03  |
# |    n_updates        | 1196      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.68e+05 |
# |    exploration_rate | 0.952     |
# | time/               |           |
# |    episodes         | 108       |
# |    fps              | 747       |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 5076      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.87e+03  |
# |    n_updates        | 1243      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.68e+05 |
# |    exploration_rate | 0.95      |
# | time/               |           |
# |    episodes         | 112       |
# |    fps              | 747       |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 5264      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.22e+03  |
# |    n_updates        | 1290      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.68e+05 |
# |    exploration_rate | 0.948     |
# | time/               |           |
# |    episodes         | 116       |
# |    fps              | 747       |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 5452      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.2e+03   |
# |    n_updates        | 1337      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.66e+05 |
# |    exploration_rate | 0.946     |
# | time/               |           |
# |    episodes         | 120       |
# |    fps              | 746       |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 5640      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.18e+03  |
# |    n_updates        | 1384      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.66e+05 |
# |    exploration_rate | 0.945     |
# | time/               |           |
# |    episodes         | 124       |
# |    fps              | 748       |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 5828      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.35e+03  |
# |    n_updates        | 1431      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.66e+05 |
# |    exploration_rate | 0.943     |
# | time/               |           |
# |    episodes         | 128       |
# |    fps              | 746       |
# |    time_elapsed     | 8         |
# |    total_timesteps  | 6016      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.31e+03  |
# |    n_updates        | 1478      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.66e+05 |
# |    exploration_rate | 0.941     |
# | time/               |           |
# |    episodes         | 132       |
# |    fps              | 748       |
# |    time_elapsed     | 8         |
# |    total_timesteps  | 6204      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.91e+03  |
# |    n_updates        | 1525      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.66e+05 |
# |    exploration_rate | 0.939     |
# | time/               |           |
# |    episodes         | 136       |
# |    fps              | 749       |
# |    time_elapsed     | 8         |
# |    total_timesteps  | 6392      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.64e+03  |
# |    n_updates        | 1572      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.66e+05 |
# |    exploration_rate | 0.937     |
# | time/               |           |
# |    episodes         | 140       |
# |    fps              | 751       |
# |    time_elapsed     | 8         |
# |    total_timesteps  | 6580      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.23e+03  |
# |    n_updates        | 1619      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.66e+05 |
# |    exploration_rate | 0.936     |
# | time/               |           |
# |    episodes         | 144       |
# |    fps              | 749       |
# |    time_elapsed     | 9         |
# |    total_timesteps  | 6768      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.57e+03  |
# |    n_updates        | 1666      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.66e+05 |
# |    exploration_rate | 0.934     |
# | time/               |           |
# |    episodes         | 148       |
# |    fps              | 751       |
# |    time_elapsed     | 9         |
# |    total_timesteps  | 6956      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.93e+03  |
# |    n_updates        | 1713      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.65e+05 |
# |    exploration_rate | 0.932     |
# | time/               |           |
# |    episodes         | 152       |
# |    fps              | 750       |
# |    time_elapsed     | 9         |
# |    total_timesteps  | 7144      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.59e+03  |
# |    n_updates        | 1760      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.65e+05 |
# |    exploration_rate | 0.93      |
# | time/               |           |
# |    episodes         | 156       |
# |    fps              | 750       |
# |    time_elapsed     | 9         |
# |    total_timesteps  | 7332      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.02e+03  |
# |    n_updates        | 1807      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.65e+05 |
# |    exploration_rate | 0.929     |
# | time/               |           |
# |    episodes         | 160       |
# |    fps              | 751       |
# |    time_elapsed     | 10        |
# |    total_timesteps  | 7520      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.3e+03   |
# |    n_updates        | 1854      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.65e+05 |
# |    exploration_rate | 0.927     |
# | time/               |           |
# |    episodes         | 164       |
# |    fps              | 750       |
# |    time_elapsed     | 10        |
# |    total_timesteps  | 7708      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.44e+03  |
# |    n_updates        | 1901      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.65e+05 |
# |    exploration_rate | 0.925     |
# | time/               |           |
# |    episodes         | 168       |
# |    fps              | 751       |
# |    time_elapsed     | 10        |
# |    total_timesteps  | 7896      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3e+03     |
# |    n_updates        | 1948      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.65e+05 |
# |    exploration_rate | 0.923     |
# | time/               |           |
# |    episodes         | 172       |
# |    fps              | 751       |
# |    time_elapsed     | 10        |
# |    total_timesteps  | 8084      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.43e+03  |
# |    n_updates        | 1995      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.65e+05 |
# |    exploration_rate | 0.921     |
# | time/               |           |
# |    episodes         | 176       |
# |    fps              | 751       |
# |    time_elapsed     | 11        |
# |    total_timesteps  | 8272      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.18e+03  |
# |    n_updates        | 2042      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.64e+05 |
# |    exploration_rate | 0.92      |
# | time/               |           |
# |    episodes         | 180       |
# |    fps              | 751       |
# |    time_elapsed     | 11        |
# |    total_timesteps  | 8460      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.4e+03   |
# |    n_updates        | 2089      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.64e+05 |
# |    exploration_rate | 0.918     |
# | time/               |           |
# |    episodes         | 184       |
# |    fps              | 751       |
# |    time_elapsed     | 11        |
# |    total_timesteps  | 8648      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.04e+03  |
# |    n_updates        | 2136      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.64e+05 |
# |    exploration_rate | 0.916     |
# | time/               |           |
# |    episodes         | 188       |
# |    fps              | 751       |
# |    time_elapsed     | 11        |
# |    total_timesteps  | 8836      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.17e+03  |
# |    n_updates        | 2183      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.64e+05 |
# |    exploration_rate | 0.914     |
# | time/               |           |
# |    episodes         | 192       |
# |    fps              | 751       |
# |    time_elapsed     | 12        |
# |    total_timesteps  | 9024      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.65e+03  |
# |    n_updates        | 2230      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.63e+05 |
# |    exploration_rate | 0.912     |
# | time/               |           |
# |    episodes         | 196       |
# |    fps              | 752       |
# |    time_elapsed     | 12        |
# |    total_timesteps  | 9212      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.51e+03  |
# |    n_updates        | 2277      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.62e+05 |
# |    exploration_rate | 0.911     |
# | time/               |           |
# |    episodes         | 200       |
# |    fps              | 752       |
# |    time_elapsed     | 12        |
# |    total_timesteps  | 9400      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.69e+03  |
# |    n_updates        | 2324      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.62e+05 |
# |    exploration_rate | 0.909     |
# | time/               |           |
# |    episodes         | 204       |
# |    fps              | 751       |
# |    time_elapsed     | 12        |
# |    total_timesteps  | 9588      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.68e+03  |
# |    n_updates        | 2371      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.61e+05 |
# |    exploration_rate | 0.907     |
# | time/               |           |
# |    episodes         | 208       |
# |    fps              | 751       |
# |    time_elapsed     | 13        |
# |    total_timesteps  | 9776      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.35e+03  |
# |    n_updates        | 2418      |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 47       |
# |    ep_rew_mean      | -2.6e+05 |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 751      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 9961     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.96e+03 |
# |    n_updates        | 2465     |
# ----------------------------------
# C:\Users\im_ki\anaconda3\envs\fyp\Lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=10000, episode_reward=-332164.00 +/- 0.00
# Episode length: 47.00 +/- 0.00
# -----------------------------------
# | eval/               |           |
# |    mean_ep_length   | 47        |
# |    mean_reward      | -3.32e+05 |
# | rollout/            |           |
# |    exploration_rate | 0.905     |
# | time/               |           |
# |    total_timesteps  | 10000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.85e+03  |
# |    n_updates        | 2474      |
# -----------------------------------
# New best mean reward!
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.59e+05 |
# |    exploration_rate | 0.904     |
# | time/               |           |
# |    episodes         | 216       |
# |    fps              | 739       |
# |    time_elapsed     | 13        |
# |    total_timesteps  | 10149     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.36e+03  |
# |    n_updates        | 2512      |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 47       |
# |    ep_rew_mean      | -2.6e+05 |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 740      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 10337    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.29e+03 |
# |    n_updates        | 2559     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 47       |
# |    ep_rew_mean      | -2.6e+05 |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 740      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 10525    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.03e+03 |
# |    n_updates        | 2606     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 47       |
# |    ep_rew_mean      | -2.6e+05 |
# |    exploration_rate | 0.898    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 741      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 10713    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.01e+03 |
# |    n_updates        | 2653     |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 47        |
# |    ep_rew_mean      | -2.59e+05 |
# |    exploration_rate | 0.896     |
# | time/               |           |
# |    episodes         | 232       |
# |    fps              | 740       |
# |    time_elapsed     | 14        |
# |    total_timesteps  | 10901     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.01e+03  |
# |    n_updates        | 2700      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 46.9      |
# |    ep_rew_mean      | -2.58e+05 |
# |    exploration_rate | 0.895     |
# | time/               |           |
# |    episodes         | 236       |
# |    fps              | 741       |
# |    time_elapsed     | 14        |
# |    total_timesteps  | 11084     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 1.44e+03  |
# |    n_updates        | 2745      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 46.9      |
# |    ep_rew_mean      | -2.58e+05 |
# |    exploration_rate | 0.893     |
# | time/               |           |
# |    episodes         | 240       |
# |    fps              | 742       |
# |    time_elapsed     | 15        |
# |    total_timesteps  | 11272     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.76e+03  |
# |    n_updates        | 2792      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 46.8      |
# |    ep_rew_mean      | -2.56e+05 |
# |    exploration_rate | 0.891     |
# | time/               |           |
# |    episodes         | 244       |
# |    fps              | 743       |
# |    time_elapsed     | 15        |
# |    total_timesteps  | 11448     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.74e+03  |
# |    n_updates        | 2836      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 46.8      |
# |    ep_rew_mean      | -2.56e+05 |
# |    exploration_rate | 0.889     |
# | time/               |           |
# |    episodes         | 248       |
# |    fps              | 744       |
# |    time_elapsed     | 15        |
# |    total_timesteps  | 11636     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.14e+03  |
# |    n_updates        | 2883      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 46.8      |
# |    ep_rew_mean      | -2.55e+05 |
# |    exploration_rate | 0.888     |
# | time/               |           |
# |    episodes         | 252       |
# |    fps              | 745       |
# |    time_elapsed     | 15        |
# |    total_timesteps  | 11824     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.8e+03   |
# |    n_updates        | 2930      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 46.8      |
# |    ep_rew_mean      | -2.55e+05 |
# |    exploration_rate | 0.886     |
# | time/               |           |
# |    episodes         | 256       |
# |    fps              | 746       |
# |    time_elapsed     | 16        |
# |    total_timesteps  | 12012     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.83e+03  |
# |    n_updates        | 2977      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 46.8      |
# |    ep_rew_mean      | -2.55e+05 |
# |    exploration_rate | 0.884     |
# | time/               |           |
# |    episodes         | 260       |
# |    fps              | 747       |
# |    time_elapsed     | 16        |
# |    total_timesteps  | 12200     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.4e+03   |
# |    n_updates        | 3024      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 46.8      |
# |    ep_rew_mean      | -2.55e+05 |
# |    exploration_rate | 0.882     |
# | time/               |           |
# |    episodes         | 264       |
# |    fps              | 747       |
# |    time_elapsed     | 16        |
# |    total_timesteps  | 12388     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.04e+03  |
# |    n_updates        | 3071      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 46.8      |
# |    ep_rew_mean      | -2.55e+05 |
# |    exploration_rate | 0.881     |
# | time/               |           |
# |    episodes         | 268       |
# |    fps              | 747       |
# |    time_elapsed     | 16        |
# |    total_timesteps  | 12576     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.67e+03  |
# |    n_updates        | 3118      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 46.8      |
# |    ep_rew_mean      | -2.54e+05 |
# |    exploration_rate | 0.879     |
# | time/               |           |
# |    episodes         | 272       |
# |    fps              | 748       |
# |    time_elapsed     | 17        |
# |    total_timesteps  | 12764     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.45e+03  |
# |    n_updates        | 3165      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 46.8      |
# |    ep_rew_mean      | -2.54e+05 |
# |    exploration_rate | 0.877     |
# | time/               |           |
# |    episodes         | 276       |
# |    fps              | 748       |
# |    time_elapsed     | 17        |
# |    total_timesteps  | 12952     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 1.99e+03  |
# |    n_updates        | 3212      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 46.8      |
# |    ep_rew_mean      | -2.54e+05 |
# |    exploration_rate | 0.875     |
# | time/               |           |
# |    episodes         | 280       |
# |    fps              | 747       |
# |    time_elapsed     | 17        |
# |    total_timesteps  | 13140     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.07e+03  |
# |    n_updates        | 3259      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 46.8      |
# |    ep_rew_mean      | -2.54e+05 |
# |    exploration_rate | 0.873     |
# | time/               |           |
# |    episodes         | 284       |
# |    fps              | 747       |
# |    time_elapsed     | 17        |
# |    total_timesteps  | 13328     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.89e+03  |
# |    n_updates        | 3306      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 46.8      |
# |    ep_rew_mean      | -2.54e+05 |
# |    exploration_rate | 0.872     |
# | time/               |           |
# |    episodes         | 288       |
# |    fps              | 747       |
# |    time_elapsed     | 18        |
# |    total_timesteps  | 13516     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.17e+03  |
# |    n_updates        | 3353      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 46.8      |
# |    ep_rew_mean      | -2.53e+05 |
# |    exploration_rate | 0.87      |
# | time/               |           |
# |    episodes         | 292       |
# |    fps              | 746       |
# |    time_elapsed     | 18        |
# |    total_timesteps  | 13704     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.31e+03  |
# |    n_updates        | 3400      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 46.8      |
# |    ep_rew_mean      | -2.52e+05 |
# |    exploration_rate | 0.868     |
# | time/               |           |
# |    episodes         | 296       |
# |    fps              | 746       |
# |    time_elapsed     | 18        |
# |    total_timesteps  | 13892     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.07e+03  |
# |    n_updates        | 3447      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 46.8      |
# |    ep_rew_mean      | -2.52e+05 |
# |    exploration_rate | 0.866     |
# | time/               |           |
# |    episodes         | 300       |
# |    fps              | 746       |
# |    time_elapsed     | 18        |
# |    total_timesteps  | 14080     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.41e+03  |
# |    n_updates        | 3494      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 46.8      |
# |    ep_rew_mean      | -2.52e+05 |
# |    exploration_rate | 0.864     |
# | time/               |           |
# |    episodes         | 304       |
# |    fps              | 746       |
# |    time_elapsed     | 19        |
# |    total_timesteps  | 14268     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.34e+03  |
# |    n_updates        | 3541      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 46.8      |
# |    ep_rew_mean      | -2.51e+05 |
# |    exploration_rate | 0.863     |
# | time/               |           |
# |    episodes         | 308       |
# |    fps              | 746       |
# |    time_elapsed     | 19        |
# |    total_timesteps  | 14456     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.55e+03  |
# |    n_updates        | 3588      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 46.8      |
# |    ep_rew_mean      | -2.51e+05 |
# |    exploration_rate | 0.861     |
# | time/               |           |
# |    episodes         | 312       |
# |    fps              | 745       |
# |    time_elapsed     | 19        |
# |    total_timesteps  | 14642     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.47e+03  |
# |    n_updates        | 3635      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 46.8      |
# |    ep_rew_mean      | -2.51e+05 |
# |    exploration_rate | 0.859     |
# | time/               |           |
# |    episodes         | 316       |
# |    fps              | 745       |
# |    time_elapsed     | 19        |
# |    total_timesteps  | 14830     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.59e+03  |
# |    n_updates        | 3682      |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 46.8     |
# |    ep_rew_mean      | -2.5e+05 |
# |    exploration_rate | 0.857    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 746      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 15018    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.81e+03 |
# |    n_updates        | 3729     |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 46.8      |
# |    ep_rew_mean      | -2.49e+05 |
# |    exploration_rate | 0.856     |
# | time/               |           |
# |    episodes         | 324       |
# |    fps              | 745       |
# |    time_elapsed     | 20        |
# |    total_timesteps  | 15204     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.67e+03  |
# |    n_updates        | 3775      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 46.8      |
# |    ep_rew_mean      | -2.49e+05 |
# |    exploration_rate | 0.854     |
# | time/               |           |
# |    episodes         | 328       |
# |    fps              | 745       |
# |    time_elapsed     | 20        |
# |    total_timesteps  | 15392     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.39e+03  |
# |    n_updates        | 3822      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 46.8      |
# |    ep_rew_mean      | -2.48e+05 |
# |    exploration_rate | 0.852     |
# | time/               |           |
# |    episodes         | 332       |
# |    fps              | 743       |
# |    time_elapsed     | 20        |
# |    total_timesteps  | 15580     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.45e+03  |
# |    n_updates        | 3869      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 46.8      |
# |    ep_rew_mean      | -2.49e+05 |
# |    exploration_rate | 0.85      |
# | time/               |           |
# |    episodes         | 336       |
# |    fps              | 743       |
# |    time_elapsed     | 21        |
# |    total_timesteps  | 15768     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.47e+03  |
# |    n_updates        | 3916      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 46.8      |
# |    ep_rew_mean      | -2.48e+05 |
# |    exploration_rate | 0.848     |
# | time/               |           |
# |    episodes         | 340       |
# |    fps              | 742       |
# |    time_elapsed     | 21        |
# |    total_timesteps  | 15950     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.28e+03  |
# |    n_updates        | 3962      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 46.9      |
# |    ep_rew_mean      | -2.49e+05 |
# |    exploration_rate | 0.847     |
# | time/               |           |
# |    episodes         | 344       |
# |    fps              | 742       |
# |    time_elapsed     | 21        |
# |    total_timesteps  | 16138     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.82e+03  |
# |    n_updates        | 4009      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 46.9      |
# |    ep_rew_mean      | -2.49e+05 |
# |    exploration_rate | 0.845     |
# | time/               |           |
# |    episodes         | 348       |
# |    fps              | 742       |
# |    time_elapsed     | 21        |
# |    total_timesteps  | 16326     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.42e+03  |
# |    n_updates        | 4056      |
# -----------------------------------
# ...
# |    episodes         | 13624    |
# |    fps              | 511      |
# |    time_elapsed     | 794      |
# |    total_timesteps  | 406664   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.22e+03 |
# |    n_updates        | 101640   |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 28.1      |
# |    ep_rew_mean      | -3.69e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 13628     |
# |    fps              | 511       |
# |    time_elapsed     | 794       |
# |    total_timesteps  | 406771    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 6.14e+03  |
# |    n_updates        | 101667    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 28.1      |
# |    ep_rew_mean      | -3.71e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 13632     |
# |    fps              | 511       |
# |    time_elapsed     | 795       |
# |    total_timesteps  | 406878    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.3e+03   |
# |    n_updates        | 101694    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 28.1      |
# |    ep_rew_mean      | -3.69e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 13636     |
# |    fps              | 511       |
# |    time_elapsed     | 795       |
# |    total_timesteps  | 406982    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.89e+03  |
# |    n_updates        | 101720    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 28.3      |
# |    ep_rew_mean      | -3.96e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 13640     |
# |    fps              | 511       |
# |    time_elapsed     | 795       |
# |    total_timesteps  | 407109    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 6.14e+03  |
# |    n_updates        | 101752    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 28.3      |
# |    ep_rew_mean      | -3.96e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 13644     |
# |    fps              | 511       |
# |    time_elapsed     | 796       |
# |    total_timesteps  | 407215    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.1e+03   |
# |    n_updates        | 101778    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 27.9      |
# |    ep_rew_mean      | -3.51e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 13648     |
# |    fps              | 511       |
# |    time_elapsed     | 796       |
# |    total_timesteps  | 407320    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.15e+03  |
# |    n_updates        | 101804    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 27.7      |
# |    ep_rew_mean      | -3.29e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 13652     |
# |    fps              | 511       |
# |    time_elapsed     | 797       |
# |    total_timesteps  | 407429    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 6.43e+03  |
# |    n_updates        | 101832    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 27.5      |
# |    ep_rew_mean      | -3.05e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 13656     |
# |    fps              | 510       |
# |    time_elapsed     | 797       |
# |    total_timesteps  | 407534    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.64e+03  |
# |    n_updates        | 101858    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 27.2      |
# |    ep_rew_mean      | -2.77e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 13660     |
# |    fps              | 510       |
# |    time_elapsed     | 797       |
# |    total_timesteps  | 407637    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.26e+03  |
# |    n_updates        | 101884    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 27.1      |
# |    ep_rew_mean      | -2.68e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 13664     |
# |    fps              | 510       |
# |    time_elapsed     | 798       |
# |    total_timesteps  | 407743    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 6.14e+03  |
# |    n_updates        | 101910    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 27.1      |
# |    ep_rew_mean      | -2.64e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 13668     |
# |    fps              | 510       |
# |    time_elapsed     | 798       |
# |    total_timesteps  | 407852    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.72e+03  |
# |    n_updates        | 101937    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 27.1      |
# |    ep_rew_mean      | -2.58e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 13672     |
# |    fps              | 510       |
# |    time_elapsed     | 799       |
# |    total_timesteps  | 407956    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 5.79e+03  |
# |    n_updates        | 101963    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 27        |
# |    ep_rew_mean      | -2.54e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 13676     |
# |    fps              | 510       |
# |    time_elapsed     | 799       |
# |    total_timesteps  | 408066    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 5.17e+03  |
# |    n_updates        | 101991    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 27        |
# |    ep_rew_mean      | -2.57e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 13680     |
# |    fps              | 510       |
# |    time_elapsed     | 799       |
# |    total_timesteps  | 408173    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 5.24e+03  |
# |    n_updates        | 102018    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 27.1      |
# |    ep_rew_mean      | -2.62e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 13684     |
# |    fps              | 510       |
# |    time_elapsed     | 800       |
# |    total_timesteps  | 408282    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.33e+03  |
# |    n_updates        | 102045    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 27.3      |
# |    ep_rew_mean      | -2.83e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 13688     |
# |    fps              | 510       |
# |    time_elapsed     | 800       |
# |    total_timesteps  | 408408    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.54e+03  |
# |    n_updates        | 102076    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 27.3      |
# |    ep_rew_mean      | -2.81e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 13692     |
# |    fps              | 509       |
# |    time_elapsed     | 801       |
# |    total_timesteps  | 408512    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 8.83e+03  |
# |    n_updates        | 102102    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 27.3      |
# |    ep_rew_mean      | -2.82e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 13696     |
# |    fps              | 509       |
# |    time_elapsed     | 801       |
# |    total_timesteps  | 408620    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.3e+03   |
# |    n_updates        | 102129    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 27.2      |
# |    ep_rew_mean      | -2.79e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 13700     |
# |    fps              | 509       |
# |    time_elapsed     | 801       |
# |    total_timesteps  | 408726    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4e+03     |
# |    n_updates        | 102156    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 27.2      |
# |    ep_rew_mean      | -2.77e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 13704     |
# |    fps              | 509       |
# |    time_elapsed     | 802       |
# |    total_timesteps  | 408832    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.44e+03  |
# |    n_updates        | 102182    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 27.2      |
# |    ep_rew_mean      | -2.78e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 13708     |
# |    fps              | 509       |
# |    time_elapsed     | 802       |
# |    total_timesteps  | 408937    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.12e+03  |
# |    n_updates        | 102209    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 27.2      |
# |    ep_rew_mean      | -2.77e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 13712     |
# |    fps              | 509       |
# |    time_elapsed     | 803       |
# |    total_timesteps  | 409042    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.38e+03  |
# |    n_updates        | 102235    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 27        |
# |    ep_rew_mean      | -2.51e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 13716     |
# |    fps              | 509       |
# |    time_elapsed     | 803       |
# |    total_timesteps  | 409148    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 3.56e+03  |
# |    n_updates        | 102261    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 27        |
# |    ep_rew_mean      | -2.51e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 13720     |
# |    fps              | 509       |
# |    time_elapsed     | 803       |
# |    total_timesteps  | 409256    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.2e+03   |
# |    n_updates        | 102288    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 27        |
# |    ep_rew_mean      | -2.47e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 13724     |
# |    fps              | 509       |
# |    time_elapsed     | 804       |
# |    total_timesteps  | 409361    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.84e+03  |
# |    n_updates        | 102315    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 27        |
# |    ep_rew_mean      | -2.48e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 13728     |
# |    fps              | 508       |
# |    time_elapsed     | 804       |
# |    total_timesteps  | 409469    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 9e+03     |
# |    n_updates        | 102342    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 26.9      |
# |    ep_rew_mean      | -2.45e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 13732     |
# |    fps              | 508       |
# |    time_elapsed     | 804       |
# |    total_timesteps  | 409573    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 2.28e+03  |
# |    n_updates        | 102368    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 27        |
# |    ep_rew_mean      | -2.46e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 13736     |
# |    fps              | 508       |
# |    time_elapsed     | 805       |
# |    total_timesteps  | 409678    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.41e+03  |
# |    n_updates        | 102394    |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 27        |
# |    ep_rew_mean      | -2.43e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 13740     |
# |    fps              | 508       |
# |    time_elapsed     | 805       |
# |    total_timesteps  | 409806    |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 4.91e+03  |
# |    n_updates        | 102426    |
# -----------------------------------

# %%
evaluate_policy(model1, env, n_eval_episodes = 10)
# Out:
# C:\Users\im_ki\anaconda3\envs\fyp\Lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (-420474.0, 0.0)

# %%
evaluate_policy(model2, env, n_eval_episodes = 10)
# Out:
# (-321641.0, 0.0)

# %%
evaluate_policy(model3, env, n_eval_episodes = 10)
# Out:
# (-14355.0, 0.0)

# %%
for x in range(10):
    obs, info = env.reset()
    result = 0
    for i in range(100):
        action, _states = model1.predict(obs)
        obs, reward, done, force_stop, info = env.step(action)
        result += reward
        
        if done or force_stop:
            break
    
    print(env.tour)
    print(len(env.tour))
    print(result)
    print("---------------------------------")
# Out:
# [0, 17, 21, 20, 14, 23, 6, 4, 11, 14, 3, 20, 11, 16, 13, 16, 3, 17, 14, 20, 10, 17, 7, 16, 16, 1, 8, 2, 7, 0, 5, 22, 3, 4, 9, 5, 9, 5, 14, 19, 14, 11, 11, 22, 19, 16, 22, 20]
# 48
# -263632
# -263632
# ---------------------------------
# [0, 1, 19, 9, 11, 5, 15, 14, 0, 18, 19, 5, 17, 16, 3, 16, 10, 13, 7, 14, 14, 12, 19, 12, 2, 11, 15, 21, 20, 14, 6, 22, 13, 10, 8, 8, 2, 15, 19, 20, 2, 23, 15, 3, 6, 20, 10, 15]
# 48
# -244653
# -244653
# ---------------------------------
# [0, 16, 13, 7, 4, 7, 11, 20, 22, 10, 8, 0, 0, 2, 22, 8, 23, 1, 2, 22, 15, 8, 3, 7, 5, 19, 21, 5, 15, 17, 13, 15, 10, 4, 7, 7, 7, 19, 12, 9, 23, 9, 7, 22, 20, 12, 21, 14]
# 48
# -254219
# -254219
# ---------------------------------
# [0, 12, 19, 16, 5, 20, 0, 23, 22, 8, 0, 10, 5, 3, 2, 8, 14, 3, 21, 8, 9, 12, 22, 11, 21, 7, 8, 14, 16, 1, 2, 17, 7, 16, 15, 9, 17, 1, 20, 3, 19, 8, 8, 4, 19, 5, 12, 1]
# 48
# -264003
# -264003
# ---------------------------------
# [0, 15, 18, 18, 9, 7, 14, 19, 8, 18, 12, 1, 18, 18, 23, 3, 21, 9, 16, 2, 5, 19, 23, 4, 20, 11, 16, 20, 9, 6, 6, 6, 14, 12, 16, 11, 2, 19, 4, 12, 15, 16, 8, 6, 1, 7, 12, 1]
# 48
# -282232
# -282232
# ---------------------------------
# [0, 9, 0, 9, 17, 3, 14, 17, 12, 11, 23, 18, 19, 8, 22, 11, 12, 16, 9, 21, 1, 5, 11, 0, 6, 22, 2, 15, 18, 19, 15, 17, 13, 14, 18, 17, 4, 23, 9, 6, 3, 23, 11, 4, 1, 10, 8, 10]
# 48
# -254414
# -254414
# ---------------------------------
# [0, 9, 15, 8, 2, 17, 9, 8, 21, 1, 4, 19, 5, 9, 21, 8, 6, 10, 8, 2, 13, 12, 15, 8, 9, 17, 19, 19, 11, 14, 22, 5, 19, 6, 10, 15, 20, 21, 2, 8, 9, 20, 2, 4, 4, 0, 18, 4]
# 48
# -274449
# -274449
# ---------------------------------
# [0, 8, 9, 15, 0, 21, 9, 21, 20, 21, 14, 12, 0, 23, 2, 4, 11, 7, 15, 6, 6, 17, 20, 14, 21, 15, 3, 22, 2, 7, 7, 13, 0, 19, 15, 15, 0, 12, 18, 7, 23, 8, 12, 16, 11, 11, 0, 3]
# 48
# -263936
# -263936
# ---------------------------------
# [0, 21, 3, 18, 10, 3, 3, 0, 10, 15, 17, 6, 16, 0, 22, 9, 13, 2, 14, 6, 11, 1, 22, 7, 15, 6, 23, 0, 1, 9, 9, 4, 11, 14, 0, 23, 13, 15, 14, 1, 23, 9, 9, 14, 8, 22, 22, 10]
# 48
# -273989
# -273989
# ---------------------------------
# [0, 15, 7, 21, 5, 18, 15, 10, 8, 14, 1, 13, 22, 8, 18, 12, 5, 4, 13, 7, 22, 6, 23, 10, 12, 7, 11, 1, 16, 0, 13, 17, 17, 10, 20, 2, 20, 15, 7, 15, 16, 20, 22, 23, 6, 1, 1, 0]
# 48
# -263538
# -263538
# ---------------------------------

# %%
for x in range(10):
    obs, info = env.reset()
    result = 0
    for i in range(100):
        action, _states = model2.predict(obs)
        obs, reward, done, force_stop, info = env.step(action)
        result += reward
        
        if done or force_stop:
            break
    
    print(env.tour)
    print(len(env.tour))
    print(result)
    print("---------------------------------")
# Out:
# [0, 3, 5, 16, 21, 1, 18, 4, 20, 12, 6, 13, 23, 15, 18, 8, 22, 18, 2, 8, 7, 8, 8, 22, 18, 11, 10, 3, 19, 0, 0, 6, 8, 8, 2, 8, 8, 8, 9, 8, 7, 8, 8, 0, 8, 22, 18, 3]
# 48
# -254035
# -254035
# ---------------------------------
# [0, 3, 11, 1, 16, 8, 14, 5, 1, 22, 0, 9, 20, 6, 19, 4, 14, 15, 8, 8, 7, 8, 21, 23, 1, 17, 0, 4, 8, 1, 8, 1, 1, 4, 1, 1, 4, 8, 4, 8, 3, 4, 0, 16, 0, 4, 1, 8]
# 48
# -284061
# -284061
# ---------------------------------
# [0, 3, 1, 16, 14, 1, 11, 5, 9, 8, 1, 1, 7, 12, 13, 23, 16, 20, 4, 10, 8, 18, 21, 19, 21, 8, 15, 21, 3, 21, 21, 6, 1, 7, 20, 1, 7, 7, 20, 7, 20, 3, 3, 1, 7, 7, 1, 1]
# 48
# -272829
# -272829
# ---------------------------------
# [0, 17, 1, 16, 20, 3, 2, 5, 1, 1, 1, 1, 13, 23, 21, 19, 11, 14, 12, 18, 4, 5, 1, 1, 9, 6, 1, 1, 1, 1, 1, 15, 0, 8, 1, 22, 3, 1, 7, 7, 15, 3, 1, 1, 1, 1, 1, 1]
# 48
# -244426
# -244426
# ---------------------------------
# [0, 1, 22, 8, 2, 20, 8, 1, 11, 10, 5, 7, 3, 4, 14, 16, 6, 19, 15, 8, 2, 3, 8, 21, 17, 0, 13, 14, 8, 23, 4, 7, 4, 4, 3, 4, 4, 16, 16, 21, 15, 4, 4, 4, 15, 21, 4, 4]
# 48
# -264242
# -264242
# ---------------------------------
# [0, 5, 16, 14, 13, 9, 14, 12, 7, 10, 18, 23, 20, 1, 20, 17, 3, 4, 19, 8, 6, 4, 2, 4, 4, 4, 4, 4, 7, 7, 17, 11, 16, 4, 21, 3, 1, 15, 1, 5, 16, 1, 5, 5, 5, 5, 5, 1]
# 48
# -253233
# -253233
# ---------------------------------
# [0, 11, 15, 23, 10, 9, 17, 6, 19, 5, 8, 3, 13, 5, 12, 4, 11, 1, 22, 20, 8, 19, 3, 21, 4, 4, 6, 18, 21, 11, 2, 11, 1, 0, 22, 7, 0, 0, 4, 0, 6, 21, 8, 14, 3, 3, 3, 3]
# 48
# -244565
# -244565
# ---------------------------------
# [0, 3, 11, 5, 21, 15, 4, 13, 9, 8, 1, 7, 0, 18, 23, 22, 23, 3, 6, 19, 16, 16, 3, 17, 2, 12, 7, 5, 7, 3, 4, 3, 7, 17, 20, 1, 8, 8, 8, 8, 8, 0, 3, 7, 8, 1, 14, 1]
# 48
# -244184
# -244184
# ---------------------------------
# [0, 3, 11, 5, 17, 16, 16, 4, 10, 19, 23, 20, 14, 0, 6, 12, 11, 2, 16, 1, 22, 0, 8, 3, 4, 13, 3, 8, 8, 21, 3, 3, 8, 8, 3, 11, 8, 19, 8, 4, 14, 0, 3, 8, 3, 8, 3, 18]
# 48
# -263953
# -263953
# ---------------------------------
# [0, 3, 11, 12, 22, 2, 8, 19, 7, 1, 21, 22, 14, 22, 22, 6, 4, 15, 5, 1, 13, 0, 15, 23, 10, 17, 4, 3, 17, 4, 3, 3, 4, 3, 3, 4, 20, 2, 8, 21, 4, 4, 21, 4, 4, 4, 4, 14]
# 48
# -263568
# -263568
# ---------------------------------

# %%
for x in range(10):
    obs, info = env.reset()
    result = 0
    for i in range(100):
        action, _states = model3.predict(obs)
        obs, reward, done, force_stop, info = env.step(action)
        result += reward
        
        if done or force_stop:
            break
    
    print(env.tour)
    print(len(env.tour))
    print(result)
    print("---------------------------------")
# Out:
# [0, 23, 21, 5, 18, 20, 9, 4, 6, 14, 3, 15, 17, 12, 10, 19, 20, 1, 13, 22, 16, 7, 11, 0, 0, 2, 8, 0]
# 28
# -24639
# -24639
# ---------------------------------
# [0, 23, 21, 5, 18, 20, 9, 4, 6, 16, 15, 3, 17, 12, 10, 14, 19, 22, 13, 7, 1, 11, 0, 0, 2, 8, 0]
# 27
# -14704
# -14704
# ---------------------------------
# [0, 23, 21, 5, 18, 20, 9, 4, 6, 14, 3, 12, 17, 10, 15, 19, 1, 13, 22, 16, 7, 11, 0, 0, 21, 2, 8, 0]
# 28
# -24257
# -24257
# ---------------------------------
# [0, 23, 21, 5, 18, 20, 9, 4, 6, 14, 3, 12, 17, 10, 15, 19, 1, 13, 22, 16, 7, 11, 0, 0, 2, 8, 0]
# 27
# -14355
# -14355
# ---------------------------------
# [0, 23, 21, 5, 18, 3, 9, 6, 20, 4, 12, 14, 17, 10, 15, 19, 1, 13, 22, 16, 3, 22, 7, 11, 0, 0, 20, 2, 8, 0]
# 30
# -44229
# -44229
# ---------------------------------
# [0, 23, 21, 5, 18, 20, 9, 4, 6, 14, 3, 12, 17, 10, 15, 19, 1, 13, 22, 16, 7, 11, 0, 0, 2, 1, 8, 0]
# 28
# -24278
# -24278
# ---------------------------------
# [0, 15, 6, 3, 9, 19, 14, 12, 10, 18, 1, 23, 21, 20, 5, 13, 17, 4, 22, 16, 7, 11, 0, 0, 2, 8, 0]
# 27
# -14187
# -14187
# ---------------------------------
# [0, 3, 9, 14, 6, 19, 23, 21, 4, 20, 12, 12, 18, 5, 15, 17, 10, 7, 22, 1, 13, 16, 11, 0, 0, 2, 8, 0]
# 28
# -24460
# -24460
# ---------------------------------
# [0, 23, 21, 5, 18, 20, 9, 4, 6, 14, 3, 12, 17, 10, 15, 19, 1, 13, 22, 16, 7, 11, 0, 0, 2, 8, 0]
# 27
# -14355
# -14355
# ---------------------------------
# [0, 23, 21, 5, 18, 20, 9, 4, 6, 14, 3, 12, 17, 8, 10, 8, 22, 13, 1, 16, 19, 15, 2, 7, 0, 0, 11, 0]
# 28
# -24412
# -24412
# ---------------------------------

# %%
print(gr24_opt)
# Out:
# NAME: gr24.opt.tour
# COMMENT: Optimal solution for gr24 (1272)
# TYPE: TOUR
# DIMENSION: 24
# TOUR_SECTION:
# 16 11 3 7 6 24 8 21 5 10 17 22 18 19 15 2 20 14 13 9 23 4 12 1 -1
# -1
# EOF

# %%
tensor_path = tempfile.gettempdir() + '\\.tensorboard-info'
print(tensor_path)
# !taskkill /IM "tensorboard.exe" /F
# Out:
# C:\Users\im_ki\AppData\Local\Temp\.tensorboard-info

# %%
# %tensorboard --logdir='F:\UCL\Year_3\FYP\src\Training\Logs\PPO_1'
# Out:
#       <iframe id="tensorboard-frame-3306c4bbdce4418e" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-3306c4bbdce4418e");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir='F:\UCL\Year_3\FYP\src\Training\Logs\A2C_1'
# Out:
#       <iframe id="tensorboard-frame-78a95f2a36bc17a0" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-78a95f2a36bc17a0");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# %tensorboard --logdir='F:\UCL\Year_3\FYP\src\Training\Logs\DQN_2'
# Out:
#       <iframe id="tensorboard-frame-21361ef9b0a502cb" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-21361ef9b0a502cb");
#           const url = new URL("/", window.location);
#           const port = 6008;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
PPO_Path  = os.path.join('Training', 'Saved Models', 'PPO_Model')
A2C_Path  = os.path.join('Training', 'Saved Models', 'A2C_Model')
model1.save()
model2.save()

# %%
best_model_path = os.path.join('Training', 'Saved Models', 'best_model')

# %%
model4 = DQN.load(best_model_path, env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
evaluate_policy(model4, env, n_eval_episodes = 10)
# Out:
# (16409.0, 0.0)

# %%
best_r = 0 
for x in range(10000):
    obs, info = env.reset()
    result = 0
    for i in range(48):
        action, _states = model4.predict(obs)
        obs, reward, done, force_stop, info = env.step(action)
        result += reward
        
        if done or force_stop:
            break
    if result > best_r:
        best_r = result
        print(env.tour)
        print(len(env.tour))
        print(result)
        print("---------------------------------")
# Out:
# [0, 5, 20, 2, 10, 18, 3, 7, 4, 1, 19, 8, 16, 14, 23, 9, 13, 22, 12, 11, 15, 6, 17, 21, 0]
# 25
# 16409
# ---------------------------------
# [0, 5, 20, 2, 10, 18, 11, 23, 14, 21, 7, 19, 4, 8, 12, 13, 22, 1, 16, 9, 3, 15, 6, 17, 0]
# 25
# 16411
# ---------------------------------
# [0, 5, 20, 2, 10, 18, 3, 7, 4, 1, 19, 14, 8, 16, 23, 9, 13, 22, 12, 11, 15, 6, 17, 21, 0]
# 25
# 16452
# ---------------------------------
# [0, 5, 20, 2, 10, 18, 11, 23, 4, 14, 21, 7, 19, 8, 12, 13, 22, 1, 16, 9, 3, 15, 6, 17, 0]
# 25
# 16528
# ---------------------------------
# [0, 5, 20, 2, 10, 18, 3, 23, 7, 4, 19, 1, 8, 14, 16, 9, 13, 22, 12, 11, 15, 6, 17, 21, 0]
# 25
# 16638
# ---------------------------------
# [0, 5, 20, 2, 10, 7, 23, 18, 14, 1, 19, 8, 3, 4, 16, 9, 13, 22, 12, 11, 15, 6, 17, 21, 0]
# 25
# 16951
# ---------------------------------
